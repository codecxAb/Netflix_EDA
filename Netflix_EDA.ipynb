# %% [markdown]
# ##Importing the libraries Needed

# %%
import pandas as pd
import plotly.express as px
from textblob import TextBlob

# %% [markdown]
# ##Importing the csv file relative location

# %%
path = "https://raw.githubusercontent.com/codecxAb/Netflix_EDA/main/netflix.csv"
df = pd.read_csv(path, index_col= 0)

# %%
df.shape
# Out:
# (8807, 11)

# %% [markdown]
# ##Head & tail part of the data set

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
df.tail()
# Out:
#             type        title         director  \
# show_id
# s8803      Movie       Zodiac    David Fincher
# s8804    TV Show  Zombie Dumb              NaN
# s8805      Movie   Zombieland  Ruben Fleischer
# s8806      Movie         Zoom     Peter Hewitt
# s8807      Movie       Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                                  NaN            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                 date_added  release_year rating   duration  \
# show_id
# s8803    November 20, 2019          2007      R    158 min
# s8804         July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
##Information About the Dataframe

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, s1 to s8807
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 825.7+ KB

# %%
for col in df.columns:
  print(col, sep='', end=' , ')
# Out:
# type , title , director , cast , country , date_added , release_year , rating , duration , listed_in , description ,

# %% [markdown]
# ##Analyze The Rating

# %%
rate = df.groupby(['rating']).size().reset_index(name = 'counts')
rate
# Out:
#       rating  counts
# 0     66 min       1
# 1     74 min       1
# 2     84 min       1
# 3          G      41
# 4      NC-17       3
# 5         NR      80
# 6         PG     287
# 7      PG-13     490
# 8          R     799
# 9      TV-14    2160
# 10      TV-G     220
# 11     TV-MA    3207
# 12     TV-PG     863
# 13      TV-Y     307
# 14     TV-Y7     334
# 15  TV-Y7-FV       6
# 16        UR       3

# %%
rating_pie = px.pie(rate, values="counts", names = 'rating', title = 'Content Distribution rating')
rating_pie
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Analyze the Best Directors

# %%
df['director']= df['director'].fillna('not specified')
df['director']
# Out:
# show_id
# s1       Kirsten Johnson
# s2         not specified
# s3       Julien Leclercq
# s4         not specified
# s5         not specified
#               ...
# s8803      David Fincher
# s8804      not specified
# s8805    Ruben Fleischer
# s8806       Peter Hewitt
# s8807        Mozez Singh
# Name: director, Length: 8807, dtype: object

# %%
director_list= pd.DataFrame()

director_list = df['director'].str.split(",", expand = True).stack()
director_list = director_list.to_frame()

director_list.columns= ['Directors']
directors = director_list.groupby('Directors').size().reset_index(name = 'Total shows')
directors = directors[directors.Directors!= 'not specified']
directors = directors.sort_values('Total shows')
directors
# Out:
#             Directors  Total shows
# 2559  Joanna Lombardi            1
# 2801       K. Subhash            1
# 2802     K.C. Bokadia            1
# 2803   K.S. Ravikumar            1
# 2804     KVR Mahendra            1
# ...               ...          ...
# 4651      Suhas Kadav           16
# 3235     Marcus Raboy           16
# 4067      Raúl Campos           18
# 261         Jan Suter           18
# 4020    Rajiv Chilaka           22
#
# [5120 rows x 2 columns]

# %%
top10directors = directors.tail(10)
top10directors
# Out:
#                 Directors  Total shows
# 2447          Jay Chapman           12
# 3306      Martin Scorsese           12
# 5074      Youssef Chahine           12
# 1382  Cathy Garcia-Molina           13
# 2450            Jay Karas           15
# 4651          Suhas Kadav           16
# 3235         Marcus Raboy           16
# 4067          Raúl Campos           18
# 261             Jan Suter           18
# 4020        Rajiv Chilaka           22

# %%
director_barchart = px.bar(top10directors, x='Directors', y = 'Total shows', title= 'Top 10 Directors with Total shows Published')
director_barchart
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Analyze The top casts

# %%
df['cast']= df['cast'].fillna('not specified')
cast_list= pd.DataFrame()

cast_list = df['cast'].str.split(",", expand = True).stack()
cast_list = cast_list.to_frame()

cast_list.columns= ['Casts']
casts = cast_list.groupby('Casts').size().reset_index(name = 'Total shows')
casts = casts[casts.Casts!= 'not specified']
casts = casts.sort_values('Total shows')
top10casts = casts.tail(10)

casts_barchart = px.bar(top10casts, x='Casts', y ='Total shows', title = 'Total shows Done by the Cast')
casts_barchart
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Analyze The Trend of Movies & Shows

# %%
df_year = df[['type', 'release_year']]
df_year = df_year.rename(columns={ 'release_year': 'Release Year' , 'type': 'Type'})
df_year = df_year.groupby(['Release Year', 'Type']).size().reset_index(name='Total')
df_year = df_year[df_year['Release Year']>= 1950]

year_linechart = px.line(df_year, x= 'Release Year', y='Total', color='Type', title = 'Trend of Movies and Shows on Netflix')
year_linechart
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Analyze the movie Duration Time

# %%
df['Movie Duration'] = df[df['type'].str.contains('Movie', case=False)]['duration'].str.replace(' min', '').astype(float)
df['TV Show Duration'] = df[df['type'].str.contains('TV Show', case=False)]['duration']
duration_mean = df['Movie Duration'].mean()
df['Movie Duration'].fillna(value= duration_mean, inplace =True)
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water    not specified
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans    not specified
# s5       TV Show           Kota Factory    not specified
#
#                                                       cast        country  \
# show_id
# s1                                           not specified  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                           not specified            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
df_duration = df[['release_year', 'Movie Duration']]
df_duration = df_duration.groupby('release_year')['Movie Duration'].sum().reset_index()
df_duration = df_duration[df_duration['release_year']>2014]
duration_line = px.line(df_duration, x='release_year', y ='Movie Duration')
print(df_duration)
duration_line.show()
# Out:
#     release_year  Movie Duration
# 67          2015    55738.081430
# 68          2016    87043.833551
# 69          2017    99667.531658
# 70          2018   111613.330940
# 71          2019    98696.143114
# 72          2020    91052.653394
# 73          2021    58081.813805
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
average_duration_by_year= df[['release_year', 'Movie Duration']]
average_duration_by_year = average_duration_by_year.groupby('release_year')['Movie Duration'].mean().reset_index()
duration_avg_line = px.line(average_duration_by_year, x='release_year', y ='Movie Duration')
print(average_duration_by_year)
duration_avg_line.show()
# Out:
#     release_year  Movie Duration
# 0           1925       99.577187
# 1           1942       35.000000
# 2           1943       62.666667
# 3           1944       52.000000
# 4           1945       63.394297
# ..           ...             ...
# 69          2017       96.577066
# 70          2018       97.308920
# 71          2019       95.821498
# 72          2020       95.543183
# 73          2021       98.111172
#
# [74 rows x 2 columns]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Analyze the top movies & shows producing Countires

# %%
df_country = df[['country', 'release_year']]
df_country= df_country[df_country['release_year']>2009]
df_country = df_country.groupby(['country','release_year']).size().reset_index(name = 'Total published')
df_country = df_country.groupby('country').size().reset_index(name='Total')
df_country = df_country.sort_values('Total')
df_countryTop20 = df_country.tail(20)
country_bar = px.bar(df_countryTop20, x = 'Total', y = 'country', title = 'Top 20 Countries of Netflix in Show Releasing')
country_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Analyze the Sentiment Of the Contents

# %%
df_sentiment = df[['release_year', 'description']].copy()
df_sentiment['Sentiment']= ''
for index, row in df_sentiment.iterrows():
  description = row['description']
  testimonial = TextBlob(description)
  polarity = testimonial.sentiment.polarity

  if polarity == 0:
    sentiment = 'Neutral'
  elif polarity <= 0:
    sentiment = "Negetive"
  else:
    sentiment = 'Positive'

  df_sentiment.loc[index, 'Sentiment']= sentiment
df_sentiment = df_sentiment[df_sentiment['release_year']>=2000]
df_sentiment = df_sentiment.groupby(['release_year', 'Sentiment']).size().reset_index(name= 'total')
sentiment_chart = px.bar(df_sentiment , x = 'release_year', y = 'total', color = 'Sentiment', title = 'Sentiment of the Content in Netflix')
sentiment_chart
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
